# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/Algorithms_CIS490_SP26/blob/main/Algorithms_Queue_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# These are class notes from 3/9/2026

# %% [markdown]
# A **Queue** data structure is also called a **First In First Out (FIFO).**
#
# A **Queue** data structure has the following functions:
#
# * enqueue(new_element) - adds new element to the "back" of the queue.
# * dequeue() - removes an element from the "front" of the queue.
# * peak() - returns the element at the "front".
# * num() - returns a count of the number of elements still in the queue.

# %% [markdown]
# A python list allows a simple implementation of a Queue, with the undesireable trait that the dequeue function is O(n) instead of O(1).

# %%
# Implement a queue with a list

class Queue:
  def __init__(self):
    self.q = []
  def enqueue(self, new_element):
    self.q.append(new_element)
  def dequeue(self):
    self.q.pop(0)
  def peek(self):
    return self.q[0]
  def num(self):
    return len(self.q)

# %%
# TEST CASE

q = Queue()
q.enqueue("Cue")
q.enqueue("Ayo")
q.enqueue("Damian")
print('peek should be Cue: ', q.peek()) # should be "Cue"

q.dequeue() # removes Cue
print("should be: Ayo", q.peek()) # should be "Ayo"

print("should be 2: ", q.num()) # should be 2

q.dequeue() # removes "Ayo"

print("should be Damian: ", q.peek())  # should be Damian
# Out:
# peek should be Cue:  Cue
# should be: Ayo Ayo
# should be 2:  2
# should be Damian:  Damian

# %% [markdown]
# Challenge: Create a new class FastQueue, in which the average dequeue time complexity is O(1) instead of O(n).

# %%
class FastQueue:
  def __init__(self):
    self.l = [0] * 100 # start with 100 spots
    self.end = 0
    self.front = 0
  def enqueue(self, new_element):
    # insert a new person at the end
    self.l[self.end] = new_element
