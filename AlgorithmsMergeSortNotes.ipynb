# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/Algorithms_CIS490_SP26/blob/main/AlgorithmsMergeSortNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * We will go over the MergeSort algorithm.
# * We will learn how to use python list append and extend methods for list objects.

# %%
alist = [3, 5, 7]
print(alist[0])
# Out:
# 3
